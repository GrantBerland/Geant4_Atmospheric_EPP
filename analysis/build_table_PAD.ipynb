# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pickle

import os
import re
from collections import OrderedDict

import seaborn as sns
sns.set_theme(font_scale=1.5);

# %%
Earray   = np.round(np.logspace(np.log10(0.250), np.log10(10000), 100), 2)
h        = np.linspace(0, 499, 500);
binWidth = np.hstack([np.diff(Earray), np.diff(Earray)[-1]]);

def ProcessIoniData(data):
    
    lineNo = 1000
    
    nRuns  = int(len(data)/lineNo)
    
    mean = np.zeros([1000])
    std  = np.zeros([1000])
    for i in range(0, nRuns):
        
        mean += data.E.values[i*lineNo:(i+1)*lineNo]
        
        std  += (data.E.values[i*lineNo:(i+1)*lineNo])**2
        
    std -= (mean/nRuns)**2
    
    std[std < 0] = 0
    
    std = np.sqrt(1/(nRuns-1) * std)
    
    return mean, std

def ProcessSpectralData(data):
    
    lineNo = 1000
    
    nRuns  = int(len(data)/lineNo)
    
    data.fillna(data.mean(), inplace=True)

    mean = np.zeros([lineNo, 100]);
    std  = np.zeros([lineNo, 100]);
    for i in range(0, nRuns):
        mean += data.values[lineNo*i:lineNo*(i+1), :]
        std  += (data.values[lineNo*i:lineNo*(i+1), :])**2
        
    std -= (mean/nRuns)**2
    
    std[std < 0] = 0
    
    std = np.sqrt(1/(nRuns-1) * std)
    
    return mean/binWidth, std/binWidth

# %% [markdown]
# From sin(a$\alpha$) from $\alpha \in [0, 45^\circ]$,
#
# $$N_{n=1} = 2 \pi \int_{0}^{45^\circ} sin^2(\alpha)~ d\alpha = 0.89660$$
#
# $$\frac{1}{2\pi N_n} \frac{d^3 N}{dt ~dA ~d\Omega} = f_0 \rightarrow \frac{N}{2\pi N_n} = f_0$$

# %%
normFactor = 1e4

# %%
for f in os.listdir("../data/PADruns_test2/"):    
    tmp = f.split('_')
        
    particle = tmp[0]
    fileType = tmp[1]
    
    E = int(re.findall(r'\d+', f)[0])
    PAD_ang = int(re.findall(r'\d+', tmp[-1].split('.')[0])[0])

    print(f + " | " + particle + " | " +  fileType + " | " +  str(E) + " | " +  str(PAD_ang))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-0b7e495df5d5> in <module>
#       6
#       7     E = int(re.findall(r'\d+', f)[0])
# ----> 8     PAD_ang = int(re.findall(r'\d+', tmp[-1].split('.')[0])[0])
#       9
#      10     print(f + " | " + particle + " | " +  fileType + " | " +  str(E) + " | " +  str(PAD_ang))
#
# IndexError: list index out of range

# %%
def build_table(path, energyDist):

    files = os.listdir(path)
    
    D = OrderedDict()
    
    files = [f for f in files if energyDist in f]
    
    for file in files:
        tmp = file.split('_')
        
        particle = tmp[0]
        fileType = tmp[1]
        E = int(re.findall(r'\d+', file)[0])
        PAD_ang = int(re.findall(r'\d+', tmp[-2].split('.')[0])[0])
        


        if fileType == "ene":
            fileType = "spectra"
            readIn = pd.read_csv(path + file, names=Earray)
            mean, std = np.divide(ProcessSpectralData(readIn), normFactor)
            
            mean = mean[:500, :]
            std  = std[:500, :]

        elif fileType == "dep":
            fileType = "ioni"
            readIn = pd.read_csv(path + file, names=['E'])
            mean, std = np.divide(ProcessIoniData(readIn), normFactor)
            mean = mean[:500]
            std  = std[:500]

        D[(particle, fileType, E, PAD_ang)] = (mean, std)
        
    return D

D_mono = build_table("../data/PADruns_test/", "mono")

# %%
filename = "G4data_mono_discretePAD.pkl"

with open(filename, 'wb') as f:
    pickle.dump(D_mono, f, protocol=pickle.HIGHEST_PROTOCOL)

D_mono = pickle.load(open(filename, 'rb'))
   
'''
filename = "G4data_sin45_exp.pkl"

with open(filename, 'wb') as f:
    pickle.dump(D_exp, f, protocol=pickle.HIGHEST_PROTOCOL)
    
D_exp = pickle.load(open(filename, 'rb'))

    
# !cp G4data_sin45_mono.pkl G4data_sin45_exp.pkl ../../G4EPP-git/G4EPP/data/
''';

'''
# Test
del D
    
with open(filename, 'rb') as f:
    D = pickle.load(f)
''';

# %%
runList = [10, 20, 50, 100, 200, 500, 1000, 2000, 5000]#, 10000]

Sig = 10

PAD = 0

plt.figure(figsize=(16,8)); 

for PAD_ang in [0, 1]:
    plt.subplot(1,2,PAD_ang+1); plt.grid(True, which='both')
    for item in runList:
        plt.semilogx((D_mono[('electron', 'ioni', item, PAD_ang)][0] + 
                      D_mono[('photon', 'ioni', item, PAD_ang)][0]), 
                     h, label="%.0f keV" % item, linewidth=1);

        #plt.semilogx((D_mono[('electron', 'ioni', item)][0] + D_mono[('photon', 'ioni', item)][0]) + 
        #             Sig*(D_mono[('electron', 'ioni', item)][1] + D_mono[('photon', 'ioni', item)][1])
        #             , h, '--');
        #
        #plt.semilogx((D_mono[('electron', 'ioni', item)][0] + D_mono[('photon', 'ioni', item)][0]) - 
        #             Sig*(D_mono[('electron', 'ioni', item)][1] + D_mono[('photon', 'ioni', item)][1]), 
        #             h, '--', linewidth=1);

    plt.xlabel('Deposited Energy [keV / km / cm$^{-2}$ sec$^{-1}$ sr$^{-1}$]');
    plt.ylabel('Altitude [km]');
    plt.legend();
    plt.ylim(0, 300);
    #plt.xlim(1e-5, 1e3);
    plt.title('Monoenergetic, PA = %.0f$^\circ$' % PAD_ang);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c6d203804470> in <module>
#      10     plt.subplot(1,2,PAD_ang+1); plt.grid(True, which='both')
#      11     for item in runList:
# ---> 12         plt.semilogx((D_mono[('electron', 'ioni', item, PAD_ang)][0] +
#      13                       D_mono[('photon', 'ioni', item, PAD_ang)][0]),
#      14                      h, label="%.0f keV" % item, linewidth=1);
#
# KeyError: ('electron', 'ioni', 10, 0)

# %%
runList = [10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]

X, Y = np.meshgrid(Earray, h)

from matplotlib.colors import LogNorm

Sig = 10

PAD = 0

Erun = 10

plt.figure(figsize=(16,8)); 

for PAD in [0]:
    plt.subplot(1,2,PAD+1); plt.grid(True, which='both')
    for item in [Erun]:
        #plt.pcolormesh(X, Y, (D_mono[('electron', 'spectra', item, PAD)][0] +
        #                      D_mono[('photon', 'spectra', item, PAD)][0]), 
        #             norm=LogNorm());
        
        plt.pcolormesh(X, Y, D_mono[('electron', 'spectra', item, PAD)][0], norm=LogNorm());

        plt.colorbar()

    plt.xlabel('Deposited Energy [keV / km / cm$^{-2}$ sec$^{-1}$ sr$^{-1}$]');
    plt.ylabel('Altitude [km]');
    plt.ylim(0, 300);
    plt.xscale('log');
    plt.title('Monoenergetic, PA = %.0f$^\circ$' % PAD);
    
    
plt.subplot(1,2,2); plt.grid(True, which='both')
for PAD in [1]:
    for item in [Erun]:
        #plt.pcolormesh(X, Y, (D_mono[('electron', 'spectra', item, PAD)][0] +
        #                      D_mono[('photon', 'spectra', item, PAD)][0]), 
        #             norm=LogNorm());
        
        plt.pcolormesh(X, Y, D_mono[('electron', 'spectra', 10, PAD)][0],
             norm=LogNorm());
        
        plt.colorbar(label='Flux [cm$^{-2}$ sec$^{-1}$ sr$^{-1}$ keV$^{-1}$]');

    plt.xlabel('Deposited Energy [keV / km / cm$^{-2}$ sec$^{-1}$ sr$^{-1}$]');
    plt.ylabel('Altitude [km]');
    plt.ylim(0, 300);
    plt.xscale('log');
    plt.title('Monoenergetic, PA = %.0f$^\circ$' % PAD);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-22f7e286e78d> in <module>
#      20         #             norm=LogNorm());
#      21
# ---> 22         plt.pcolormesh(X, Y, D_mono[('electron', 'spectra', item, PAD)][0], norm=LogNorm());
#      23
#      24         plt.colorbar()
#
# KeyError: ('electron', 'spectra', 10, 0)

# %%
plt.figure(figsize=(8,6));

plt.semilogx(D_mono[('electron', 'ioni', 10,  0)][0], h)
plt.semilogx(D_mono[('electron', 'ioni', 100, 0)][0], h);

plt.semilogx(D_mono[('electron', 'ioni', 10,  1)][0], h, '--')
plt.semilogx(D_mono[('electron', 'ioni', 100, 1)][0], h, '--');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-53a3788c5427> in <module>
#       1 plt.figure(figsize=(8,6));
#       2
# ----> 3 plt.semilogx(D_mono[('electron', 'ioni', 10,  0)][0], h)
#       4 plt.semilogx(D_mono[('electron', 'ioni', 100, 0)][0], h);
#       5
#
# KeyError: ('electron', 'ioni', 10, 0)

# %%
from scipy.signal import savgol_filter

energy = 1000

plt.figure(figsize=(16,12)); plt.subplot(1,2,1); plt.grid(True, which='both')
#for i in [0, 70]:
for i in range(0, 72):
    if i % 5 == 0:
        label = '%.0f$^\circ$' % i
        print("%.0f deg ~ %.3f keV/part" % (i, np.sum(D_mono[('electron', 'ioni', energy, i)][0])/1e4))

    else: 
        label = None
    plt.semilogx(D_mono[('electron', 'ioni', energy, i)][0], h, 
                 label=label, linewidth=0.75)
    


plt.legend();
#plt.yscale('log')
#plt.ylim([1e1, 300]);
#plt.xlim([1e-6, 1e4]);
plt.ylabel('Altitude [km]');
plt.xlabel('Deposited Energy [keV/km]');

plt.subplot(1,2,2); plt.grid(True, which='both');

for i in range(0, 72):
    plt.plot(i, np.max(D_mono[('electron', 'ioni', energy, i)][0]), 'k.')
    
    
coef = 5.3e3
plt.plot(range(0, 72), coef*np.sin(np.deg2rad(range(0, 72))), label=r'%.1e * sin($\alpha$)' % coef)
plt.ylabel('I$_{max}$ [keV]');
plt.xlabel('Pitch Angle [deg]');
plt.legend();

plt.ylim(0, 5000);


#plt.yscale('log');
#plt.xscale('log');
# Out:
# 0 deg ~ 0.098 keV/part
# 5 deg ~ 0.591 keV/part
# 10 deg ~ 1.083 keV/part
# 15 deg ~ 1.575 keV/part
# 20 deg ~ 2.065 keV/part
# 25 deg ~ 2.554 keV/part
# 30 deg ~ 3.040 keV/part
# 35 deg ~ 3.521 keV/part
# 40 deg ~ 3.998 keV/part
# 45 deg ~ 4.468 keV/part
# 50 deg ~ 4.928 keV/part
# 55 deg ~ 5.378 keV/part
# 60 deg ~ 5.811 keV/part
# 65 deg ~ 6.225 keV/part
# 70 deg ~ 6.611 keV/part

# %%
from scipy.signal import savgol_filter

energy = 1000

plt.figure(figsize=(16,12)); plt.subplot(1,2,1); plt.grid(True, which='both')
#for i in [0, 70]:
for i in range(0, 72):
    if i % 5 == 0:
        label = '%.0f$^\circ$' % i
        print("%.0f deg ~ %.3f keV/part" % (i, np.sum(D_mono[('photon', 'ioni', energy, i)][0])/1e4))

    else: 
        label = None
    plt.semilogx(savgol_filter(D_mono[('photon', 'ioni', energy, i)][0], 5, 0), h, 
                 label=label, linewidth=0.75)
    


plt.legend();
#plt.yscale('log')
#plt.ylim([1e1, 300]);
#plt.xlim([1e-6, 1e4]);
plt.ylabel('Altitude [km]');
plt.xlabel('Deposited Energy [keV/km]');

plt.subplot(1,2,2); plt.grid(True, which='both');

for i in range(0, 72):
    plt.plot(i, np.max(D_mono[('photon', 'ioni', energy, i)][0]), 'k.')
    
    
coef = 2.5e-1
plt.plot(range(0, 72), coef*np.sin(np.deg2rad(range(0, 72))), label=r'%.1e * sin($\alpha$)' % coef)
plt.ylabel('I$_{max}$ [keV]');
plt.xlabel('Pitch Angle [deg]');
plt.legend();

#plt.ylim(0, 5000);


#plt.yscale('log');
#plt.xscale('log');
# Out:
# 0 deg ~ 0.000 keV/part
# 5 deg ~ 0.000 keV/part
# 10 deg ~ 0.000 keV/part
# 15 deg ~ 0.000 keV/part
# 20 deg ~ 0.000 keV/part
# 25 deg ~ 0.000 keV/part
# 30 deg ~ 0.000 keV/part
# 35 deg ~ 0.000 keV/part
# 40 deg ~ 0.000 keV/part
# 45 deg ~ 0.000 keV/part
# 50 deg ~ 0.000 keV/part
# 55 deg ~ 0.000 keV/part
# 60 deg ~ 0.000 keV/part
# 65 deg ~ 0.000 keV/part
# 70 deg ~ 0.000 keV/part
